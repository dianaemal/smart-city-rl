# %% [markdown]
# ### Disaster Messages dataset
# This dataset conians about 26K service requests from different parts of the world after a disaster (floods, earthquaks, etc)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/dianaemal/Downloads/archive-3/disaster_messages.csv")
df.head()
# Out:
#    id                                            message  \
# 0   2  Weather update - a cold front from Cuba that c...
# 1   7            Is the Hurricane over or is it not over
# 2   8                    Looking for someone but no name
# 3   9  UN reports Leogane 80-90 destroyed. Only Hospi...
# 4  12  says: west side of Haiti, rest of the country ...
#
#                                             original   genre
# 0  Un front froid se retrouve sur Cuba ce matin. ...  direct
# 1                 Cyclone nan fini osinon li pa fini  direct
# 2  Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 3  UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 4  facade ouest d Haiti et le reste du pays aujou...  direct

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26248 entries, 0 to 26247
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        26248 non-null  int64
#  1   message   26248 non-null  object
#  2   original  10184 non-null  object
#  3   genre     26248 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 820.4+ KB

# %%
df.nunique()
# Out:
# id          26180
# message     26177
# original     9630
# genre           3
# dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
print(df["message"].head(10))
# Out:
# 0                                                        Weather update - a cold front from Cuba that could pass over Haiti
# 1                                                                                   Is the Hurricane over or is it not over
# 2                                                                                           Looking for someone but no name
# 3                      UN reports Leogane 80-90 destroyed. Only Hospital St. Croix functioning. Needs supplies desperately.
# 4                                                           says: west side of Haiti, rest of the country today and tonight
# 5                                                                                    Information about the National Palace-
# 6                                                                                            Storm at sacred heart of jesus
# ...

# %% [markdown]
# ### US Consumer Complaints (CFPB Dataset)

# %%
df2 = pd.read_csv("/Users/dianaemal/Downloads/archive-4/complaints-2025-11-11_23_26.csv")

# %%
df2.shape
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372815 entries, 0 to 1372814
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   Date received                 1372815 non-null  object
#  1   Product                       1372815 non-null  object
#  2   Sub-product                   1353725 non-null  object
#  3   Issue                         1372815 non-null  object
#  4   Sub-issue                     1249332 non-null  object
#  5   Consumer complaint narrative  1372814 non-null  object
#  6   Company public response       759977 non-null   object
#  7   Company                       1372814 non-null  object
#  8   State                         1368074 non-null  object
#  9   ZIP code                      1372814 non-null  object
#  10  Tags                          136415 non-null   object
#  11  Consumer consent provided?    1372814 non-null  object
# ...

# %%
df2["Consumer complaint narrative"].head(1)
# Out:
# 0    In accordance with the Fair Credit Reporting Act, Everything has to be 100 % accurate on my credit report.\n\nThe credit burruea stated my account was properly investigated, but how is that possible If the open date isn't accurute The date last active isnt accurate. And the date last reported is inaccurate. That is grounds for removal.\n\nThey violated my rights under the 15 U.S.C. 1681, Section 602 A states I have right to privacy.\n\n15 U.S.C 1681 Section 604 also states that Consumer report agencies can not furnish my account without my permission.\n\nThey also violated my Hippa rights. \nI had no knowledge or consent of my medical info being disclosed.
# Name: Consumer complaint narrative, dtype: object

# %% [markdown]
# ### Hotel review dataset

# %%
df3 = pd.read_csv("/Users/dianaemal/Downloads/archive-4/Hotel_Reviews.csv")

# %%
df3.head(2)
# Out:
#                                                Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam Netherlands
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam Netherlands
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality  \
# 0              Russia
# 1             Ireland
#
# ...

# %%
df3.shape
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  object
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  object
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  object
#  5   Reviewer_Nationality                        515738 non-null  object
#  6   Negative_Review                             515738 non-null  object
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
# ...

# %% [markdown]
# ### Twitter customer support daatset

# %%
df4 = pd.read_csv("/Users/dianaemal/Downloads/archive-4/sample.csv")

# %%
df4.head(2)
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
#
#                                                                                                                                             text  \
# 0                                  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
#
#   response_tweet_id  in_response_to_tweet_id
# 0            119236                      NaN
# 1               NaN                 119239.0

# %%
df4.shape
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 93 non-null     int64
#  1   author_id                93 non-null     object
#  2   inbound                  93 non-null     bool
#  3   created_at               93 non-null     object
#  4   text                     93 non-null     object
#  5   response_tweet_id        65 non-null     object
#  6   in_response_to_tweet_id  68 non-null     float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 4.6+ KB
